# %% [markdown]
# # Pertemuan 1: Pengantar Python untuk Data Science
#
# | | |
# |---|---|
# | **Nama Lengkap** | Nisa Agustina Maesaroh |
# | **NIM** | 240401070509 |
# | **Kelas** | IF403 |

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat Datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat Datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Nisa Agustina Maesaroh" # String
angkatan = 2024               # Integer
ipk = 3.98                    # Float
aktif = True                  # Booelan

print(f"Nama : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Nisa Agustina Maesaroh
# Angkatan : 2024
# IPK : 3.98
# Aktif : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "Github"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. Github

# %%
# SEL 4: Fungsi Sederhana
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Nisa Agustina Maesaroh", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Nisa Agustina Maesaroh dari Informatika, angkatan 2024.

# %% [markdown]
# # Kesimpulan
#
# ## Apa yang Dipelajari
# Memahami dasar-dasar Python: tipe data primitif (int, float, str, bool), struktur data (list), perulangan, dan pembuatan fungsi sederhana.
#
# ## Temuan Utama
# Python sangat mudah dibaca dan ditulis, bahkan untuk tugas sederhana seperti menampilkan output dan membuat fungsi perkenalan. Sintaks yang bersih membuat proses belajar lebih cepat.
#
# ## Keterbatasan & Pertanyaan
# Latihan masih bersifat dasar dan belum menyentuh library khusus Data Science. Pertanyaan yang muncul: bagaimana cara kerja pandas dalam memproses data besar secara efisien?
